# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import tqdm
import matplotlib.image as Image
import random

# %% [markdown]
# ## Helper Functions

# %%
def imageToArray(image):
    img=Image.imread(image)
    img=img.reshape(-1,)
    return img

def arrayToImage(array,l,b,h):
    newimg=array.reshape(l,b,h)
    return newimg

def moduloInverse(a,m):
    for i in range(1,m):
        if (a*i)%m==1:
            return i

def isPrime(n):
    if n==2:
        return True
    if n%2==0:
        return False
    for i in range(3,int(math.sqrt(n))+1,2):
        if n%i==0:
            return False
    return True

def power(a,b,m):
    ind=1
    for i in range(0,b):
        ind=(ind*a)%m
    return ind

# %% [markdown]
# ## Prime Number Generator

# %%
def primeNumberGenerator():
    primeslist=[]
    for i in range(2,100):
        if isPrime(i):
            primeslist.append(i)
    p=1
    q=1
    while p*q<256:
        p=random.choice(primeslist)
        q=random.choice(primeslist)
    return p,q

# %% [markdown]
# ## Key Generation

# %%
def keyGeneration(p,q):
    phi=(p-1)*(q-1)
    e=random.randint(2,phi)
    while math.gcd(e,phi)!=1:
        e=random.randint(2,phi)
    d=moduloInverse(e,phi)
    return e,d

# %% [markdown]
# ## RSA Encryption

# %%
def encrypt(plainText,e,n):
    cipherText=[]
    for i in tqdm.tqdm(plainText):
        cipherText.append(power(i,e,n))
    return cipherText

# %% [markdown]
# ## RSA Decryption

# %%
def decrypt(cipherText,d,n):
    plainText=[]
    for i in tqdm.tqdm(cipherText):
        plainText.append(power(i,d,n))
    return plainText

# %% [markdown]
# ## Actual Image

# %%
img=Image.imread('cat.jpeg')
print(img.shape)
print(img)
plt.imshow(img)
# Out:
# (194, 259, 3)
# [[[151 181 207]
#   [150 180 206]
#   [148 178 206]
#   ...
#   [120 141 170]
#   [124 140 165]
#   [125 141 166]]
#
#  [[151 178 205]
#   [149 179 205]
#   [150 177 206]
#   ...
#   [123 140 156]
#   [128 141 150]
#   [128 141 150]]
#
#  [[150 176 203]
#   [150 177 204]
#   [151 177 204]
#   ...
#   [131 142 128]
#   [137 142 122]
#   [137 142 122]]
#
#  ...
#
#  [[ 41  30  28]
#   [ 38  28  26]
#   [ 34  26  24]
#   ...
#   [ 50  49  45]
#   [ 50  49  44]
#   [ 52  49  44]]
#
#  [[ 42  32  31]
#   [ 37  29  27]
#   [ 30  21  22]
#   ...
#   [ 50  46  43]
#   [ 50  46  43]
#   [ 52  47  44]]
#
#  [[ 41  33  31]
#   [ 37  29  27]
#   [ 28  22  22]
#   ...
#   [ 51  46  43]
#   [ 51  46  43]
#   [ 52  47  44]]]

# %% [markdown]
# ## Main

# %%
p,q=primeNumberGenerator()
n=p*q
e,d=keyGeneration(p,q)
print ("The public key is: ",e,n)
print ("The private key is: ",d,n)
imagePath='cat.jpeg'
image3D=Image.imread(imagePath)
l=image3D.shape[0]
b=image3D.shape[1]
h=image3D.shape[2]
intialImageVector=imageToArray(imagePath)
print ("The image in 1D is: ", intialImageVector)
cipherText=encrypt(intialImageVector,e,n)
garbageimage=cipherText
print ("The ciphertext is: ", cipherText)
plainText=decrypt(cipherText,d,n)
print ("The plaintext is: ", plainText)
plainText=np.array(plainText)
 42, 171, 125, 65, 173, 127, 67, 178, 128, 67, 179, 129, 68, 183, 129, 67, 188, 134, 72, 195, 141, 77, 200, 144, 85, 202, 136, 88, 166, 105, 51, 171, 123, 49, 143, 106, 25, 152, 122, 49, 104, 73, 16, 107, 68, 37, 143, 98, 79, 83, 31, 10, 121, 72, 40, 153, 117, 67, 155, 137, 87, 95, 101, 73, 132, 160, 164, 101, 144, 197, 107, 165, 239, 93, 163, 233, 92, 167, 234, 100, 168, 231, 105, 169, 230, 112, 168, 229, 112, 166, 226, 110, 164, 228, 108, 163, 228, 106, 166, 236, 103, 167, 239, 101, 167, 241, 100, 168, 241, 101, 168, 239, 103, 168, 236, 104, 168, 232, 104, 168, 232, 101, 168, 236, 100, 169, 238, 100, 169, 238, 100, 169, 238, 100, 169, 238, 100, 169, 238, 100, 169, 238, 100, 169, 238, 101, 170, 239, 101, 170, 239, 101, 170, 239, 101, 170, 239, 101, 170, 239, 101, 170, 239, 101, 170, 239, 101, 170, 239, 99, 169, 238, 99, 169, 238, 99, 169, 238, 99, 169, 238, 99, 169, 238, 99, 169, 238, 99, 169, 238, 99, 169, 238, 100, 170, 239, 100, 170, 239, 100, 170, 239, 99, 169, 238, 99, 169, 238, 98, 168, 237, 98, 168, 237, 98, 168, 237, 96, 166, 238, 96, 166, 238, 96, 166, 238, 96, 166, 238, 97, 167, 239, 97, 167, 239, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 98, 168, 240, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 98, 170, 244, 98, 170, 244, 98, 170, 244, 97, 169, 243, 97, 169, 243, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 96, 168, 242, 95, 169, 244, 95, 168, 245, 92, 170, 245, 91, 171, 240, 91, 171, 240, 92, 170, 242, 98, 167, 244, 105, 163, 245, 114, 160, 235, 140, 169, 227, 176, 193, 223, 209, 215, 213, 225, 224, 194, 235, 229, 181, 245, 236, 179, 252, 239, 187, 250, 240, 189, 254, 250, 202, 252, 250, 202, 254, 247, 205, 255, 245, 209, 251, 240, 210, 237, 230, 211, 216, 215, 213, 195, 205, 217, 164, 189, 219, 138, 177, 220, 115, 167, 225, 103, 168, 234, 95, 167, 239, 84, 164, 237, 79, 161, 235, 79, 166, 237, 76, 167, 237, 76, 168, 235, 80, 164, 236, 83, 161, 235, 86, 157, 237, 91, 153, 236, 94, 150, 233, 98, 149, 232, 110, 152, 234, 110, 149, 226, 106, 144, 215, 102, 140, 203, 102, 138, 196, 103, 140, 192, 105, 143, 188, 110, 144, 182, 120, 141, 170, 124, 140, 165, 125, 141, 166, 151, 178, 205, 149, 179, 205, 150, 177, 206, 147, 177, 205, 148, 175, 204, 145, 175, 203, 144, 173, 203, 143, 174, 203, 140, 171, 202, 138, 171, 202, 141, 172, 203, 140, 173, 204, 142, 175, 208, 142, 177, 209, 144, 177, 210, 143, 177, 212, 143, 176, 219, 14 ...

# %% [markdown]
# ## Image from the Ciphertext

# %%
plt.imshow(garbageImage)
# We can see that the image when encrypted and then pixels being wrapped around using modulo 256 would lead to a garbage 
# image which is a bit similar to the pattern as we have take modulo in all the pixels with the same number

# %% [markdown]
# ## Image after Decryption

# %%
plt.imshow(finalImage)
